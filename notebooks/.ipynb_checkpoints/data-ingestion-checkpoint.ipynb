# %% [markdown]
# # NVD Vulnerabilities Dataset Extraction
# ## Overview
# This script fetches cybersecurity vulnerability data from the National Vulnerability Database (NVD) using its REST API. It retrieves CVE details, CVSS scores, attack vectors, and affected operating systems.
#
# ## Key Components
# 1. Fetching Data from NVD API
#     * Uses the NVD API endpoint.
#     * Supports filtering by publication date.
#     * Handles pagination to fetch large datasets.
#     * Implements rate limiting to comply with API restrictions.
# 2. Processing Vulnerabilities
#     * Extracts key details:
#         * CVE ID (Common Vulnerabilities and Exposures identifier)
#         * Description (English version of the vulnerability summary)
#         * CVSS Score (Severity score from CVSS v3.1, v3.0, or v2)
#         * Attack Vector (Exploitability details)
#         * Affected OS (Extracted from CPE configuration data)
# 3. Data Filtering & Storage
#     * Filters vulnerabilities with both CVSS Score and Attack Vector.
#     * Converts extracted data into a structured Pandas DataFrame.
#     * Saves results as a CSV file (nvd_vulnerabilities_with_os.csv).
#
# ## Usage
# 1. Set the start_date and end_date for filtering vulnerabilities.
# 2. Run the script to retrieve and process data.
# 3. Check the output CSV for structured vulnerability records.
#
# ## Dependencies
# * Python (3.x)
# * Requests (For API communication)
# * Pandas (For data processing)
#
# Code provided by ManavKhambhayata & Ananya Verma at:\
# https://www.kaggle.com/code/manavkhambhayata/cve-2024-database-extraction-framework/notebook

# %%
import requests
import pandas as pd
import time

# NVD API URL
API_URL = "https://services.nvd.nist.gov/rest/json/cves/2.0"

# Replace with your valid API key
API_KEY = "ea5501a5-24fe-4720-80e3-2abed401d92f"

def fetch_nvd_data(start_date, end_date, results_per_page=200):
    headers = {"apiKey": API_KEY}
    params = {
        "resultsPerPage": results_per_page,
        "startIndex": 0,
        "pubStartDate": f"{start_date}T00:00:00.000Z",
        "pubEndDate": f"{end_date}T23:59:59.999Z",
    }

    all_vulnerabilities = []

    while True:
        response = requests.get(API_URL, headers=headers, params=params)

        if response.status_code == 200:
            data = response.json()
            vulnerabilities = data.get("vulnerabilities", [])
            all_vulnerabilities.extend(vulnerabilities)

            total_results = data.get("totalResults", 0)
            print(f"Fetched {len(vulnerabilities)} records. Total expected: {total_results}")

            params["startIndex"] += results_per_page
            if params["startIndex"] >= total_results:
                break

            time.sleep(6)  # Respect rate limits

        elif response.status_code == 403:
            print("Error: Invalid API Key or permissions.")
            break
        else:
            print(f"Error: {response.status_code} - {response.text}")
            break

    return all_vulnerabilities

# Example usage (dates in the future for demonstration)
start_date = "2024-01-01"
end_date = "2024-01-15"

vulnerabilities = fetch_nvd_data(start_date, end_date)

if vulnerabilities:
    filtered_data = []
    for vuln in vulnerabilities:
        cve_id = vuln["cve"]["id"]

        # Extract description
        descriptions = vuln["cve"].get("descriptions", [])
        description = next((desc["value"] for desc in descriptions if desc.get("lang") == "en"), "N/A")

        # Extract CVSS Score and Attack Vector
        metrics = vuln["cve"].get("metrics", {})
        cvss_score, attack_vector = "N/A", "N/A"

        # Check CVSS versions in priority order (v4.0 > v3.1 > v3.0)
        if "cvssMetricV40" in metrics:
            cvss_data = metrics["cvssMetricV40"][0].get("cvssData", {})
            cvss_score = cvss_data.get(["baseScore",""], "N/A")
            attack_vector = cvss_data.get("vectorString", "N/A")
        elif "cvssMetricV31" in metrics:
            cvss_data = metrics["cvssMetricV31"][0].get("cvssData", {})
            cvss_score = cvss_data.get("baseScore", "N/A")
            attack_vector = cvss_data.get("vectorString", "N/A")
        elif "cvssMetricV30" in metrics:
            cvss_data = metrics["cvssMetricV30"][0].get("cvssData", {})
            cvss_score = cvss_data.get("baseScore", "N/A")
            attack_vector = cvss_data.get("vectorString", "N/A")

        # Extract OS Information from CPE data
        os_list = set()
        configurations = vuln["cve"].get("configurations", [])
        for config in configurations:
            for node in config.get("nodes", []):
                for cpe_match in node.get("cpeMatch", []):
                    cpe_uri = cpe_match.get("criteria", "")
                    if cpe_uri.startswith("cpe:2.3:"):
                        parts = cpe_uri.split(":")
                        if len(parts) >= 5 and parts[2] == 'o':  # 'o' indicates OS
                            vendor = parts[3].replace("_", " ").title()
                            product = parts[4].replace("_", " ").title()
                            version = parts[5] if len(parts) > 5 else ""
                            if version not in ["*", "-"]:
                                os_list.add(f"{vendor} {product} {version}".strip())
                            else:
                                os_list.add(f"{vendor} {product}".strip())

        os_info = ", ".join(os_list) if os_list else "N/A"

        # Filter records with valid CVSS data
        if cvss_score != "N/A" and attack_vector != "N/A":
            filtered_data.append({
                "CVE_ID": cve_id,
                "Description": description,
                "CVSS_Score": cvss_score,
                "Attack_Vector": attack_vector,
                "Affected_OS": os_info,
                "CWE_ID": cweID,
                "Has_KEV": hasKev
            })

    df = pd.DataFrame(filtered_data)

    if not df.empty:
        #df.to_csv("../data/nvd_vulnerabilities_with_os.csv", index=False)
        print(f"Saved {len(df)} records with OS information to CSV.")
        df
    else:
        print("No records with both CVSS Score and Attack Vector found.")
#else:
#    print("No data fetched.")
# Out:
# Fetched 200 records. Total expected: 1327
# Fetched 200 records. Total expected: 1327
# Fetched 200 records. Total expected: 1327
# Fetched 200 records. Total expected: 1327
# Fetched 200 records. Total expected: 1327
# Fetched 200 records. Total expected: 1327
# Fetched 127 records. Total expected: 1327
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 109
#     101     # Filter records with valid CVSS data
#     102     if cvss_score != "N/A" and attack_vector != "N/A":
#     103         filtered_data.append({
#     104             "CVE_ID": cve_id,
#     105             "Description": description,
#     106             "CVSS_Score": cvss_score,
#     107             "Attack_Vector": attack_vector,
#     108             "Affected_OS": os_info,
# --> 109             "CVSS_v3_Metrics": cvssV3Metrics,
#     110             "CVSS_v3_Severity": cvssV3Severity,
#     111             "CWE_ID": cweID,
#     112             "Has_KEV": hasKev
#     113         })
#     115 df = pd.DataFrame(filtered_data)
#     117 if not df.empty:
#     118     #df.to_csv("../data/nvd_vulnerabilities_with_os.csv", index=False)
#
# NameError: name 'cvssV3Metrics' is not defined

# %%
import csv, json, os, time, urllib.parse, requests, re
from pathlib import Path

# --- config -----------------------------------------------------------
API_URL   = "https://services.nvd.nist.gov/rest/json/cpes/2.0"
API_KEY = "ea5501a5-24fe-4720-80e3-2abed401d92f" # Replace with your valid API key
RATE_SECS = 1.2                               # stay well under the 5-sec/req soft limit
SOURCE_TXT = Path("../data/smb-software-footprint.txt")
OUTPUT_CSV = Path("../data/smb_software_to_cpe.csv")
# ----------------------------------------------------------------------

def search_cpe(keyword: str) -> str | None:
    """Return the best-match CPE 2.3 URI for <keyword> (or None)."""
    params  = {"keywordSearch": keyword, "resultsPerPage": 20}
    headers = {"apiKey": API_KEY} if API_KEY else {}

    resp = requests.get(API_URL, params=params, headers=headers, timeout=15)
    resp.raise_for_status()
    data = resp.json()

    for item in data.get("products", []):
        # v2.0 structure: item["cpe"]["cpeName"]
        cpe = (item.get("cpe") or {}).get("cpeName") \
              or item.get("cpe23Uri")                # fallback field
        if cpe and re.search(keyword, cpe, re.I):
            return cpe

    # nothing scored as an obvious hit – return first result (if any)
    if data.get("products"):
        first = data["products"][0]
        return (first.get("cpe") or {}).get("cpeName") or first.get("cpe23Uri")

    return None

def build_mapping(src: Path, out: Path):
    rows = []
    for raw_line in src.read_text(encoding="utf-8").splitlines():
        product = raw_line.strip()
        if not product:
            continue
        cpe = search_cpe(product)
        rows.append({"product": product, "cpe_name": cpe or "NOT_FOUND"})
        print(f"{product:40} → {cpe or 'NOT_FOUND'}")
        time.sleep(RATE_SECS)
    # write CSV
    with out.open("w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["product", "cpe_name"])
        writer.writeheader()
        writer.writerows(rows)
    print(f"\n✓  Saved mapping file → {out}")

if __name__ == "__main__":
    build_mapping(SOURCE_TXT, OUTPUT_CSV)
# Out:
# Windows 10 Pro                           → cpe:2.3:o:microsoft:windows_10:-:*:*:*:*:*:x64:*
# Windows Server 2019/2022                 → NOT_FOUND
# VMware Workstation                       → cpe:2.3:a:vmware:workstation:-:*:*:*:*:*:*:*
# Oracle VM VirtualBox                     → cpe:2.3:a:oracle:vm_virtualbox:4.0:*:*:*:*:*:*:*
# QuickBooks                               → cpe:2.3:a:intuit:quickbooks:2009:*:*:*:*:*:*:*
# Sage 50cloud                             → NOT_FOUND
# Sage Intacct                             → NOT_FOUND
# Xero                                     → cpe:2.3:h:xerox:copycentre_c65:1.001.02.0715:*:*:*:*:*:*:*
# Thomson Reuters UltraTax CS              → cpe:2.3:a:thomsonreuters:ultratax_cs:2017:*:*:*:*:*:*:*
# CCH ProSystem fx Tax                     → NOT_FOUND
# Drake Tax                                → NOT_FOUND
# ATX                                      → cpe:2.3:h:atx:minicmts200a:-:*:*:*:*:*:*:*
# Practice CS                              → NOT_FOUND
# OfficeTools                              → NOT_FOUND
# DocuWare                                 → cpe:2.3:a:docuware:fulltext_server:6.11:*:*:*:*:*:*:*
# SafeSend                                 → NOT_FOUND
# Adobe Acrobat Pro                        → cpe:2.3:a:adobe:acrobat:10.0:-:pro:*:*:*:*:*
# Engagement                               → cpe:2.3:a:oracle:retail_customer_engagement:16.0:*:*:*:*:*:*:*
# CaseWare                                 → NOT_FOUND
# IDEA                                     → cpe:2.3:a:jetbrains:intellij_idea:10.5.2:*:*:*:*:*:*:*
# ACL Analytics                            → NOT_FOUND
# ProSystem fx Engagement                  → NOT_FOUND
# QuickBooks Enterprise                    → NOT_FOUND
# Sage Intacct                             → NOT_FOUND
# Microsoft Dynamics GP                    → cpe:2.3:a:microsoft:dynamics_gp:-:*:*:*:*:*:*:*
# Microsoft 365                            → cpe:2.3:a:microsoft:dynamics_365:8.0:*:*:*:*:*:*:*
# Google Workspace                         → NOT_FOUND
# Zoom                                     → cpe:2.3:a:aisquared:zoomtext:9.1:*:*:*:*:*:*:*
# GoToMeeting                              → cpe:2.3:a:citrix:gotomeeting:5.0.799.1238:-:-:*:-:android:*:*
# Microsoft Exchange                       → cpe:2.3:a:ca:unicenter_management_microsoft_exchange:-:*:*:*:*:*:*:*
# Gmail                                    → cpe:2.3:a:google:gmail:-:*:*:*:*:*:*:*
# SQL Server Express                       → cpe:2.3:a:microsoft:sql_server:2005:sp3:express:*:*:*:*:*
# SQL Server Standard                      → cpe:2.3:a:microsoft:sql_server:2012:-:standard:*:*:*:*:*
# MySQL                                    → cpe:2.3:a:mysql:maxdb:-:*:*:*:*:*:*:*
# MariaDB                                  → cpe:2.3:a:mariadb:mariadb:5.1.61:*:*:*:*:*:*:*
# NAS Devices                              → NOT_FOUND
# Synology                                 → cpe:2.3:a:synology:diskstation_manager:4.3-3810:*:*:*:*:*:*:*
# QNAP                                     → cpe:2.3:o:qnap:qts:4.1.0:*:*:*:*:*:*:*
# Windows File Server                      → cpe:2.3:a:eset:file_security:-:*:*:*:*:windows_server:*:*
# SonicWall                                → cpe:2.3:a:sonicwall:aventail_access_manager:10.1.95:*:*:*:*:*:*:*
# Ubiquiti UniFi Security Gateway          → NOT_FOUND
# Sophos XG                                → cpe:2.3:h:sophos:xg_firewall:-:*:*:*:*:*:*:*
# Bitdefender GravityZone                  → cpe:2.3:a:bitdefender:gravityzone:5.1.11.432:*:*:*:*:*:*:*
# Trend Micro Worry-Free                   → cpe:2.3:a:trendmicro:worry-free_business_security:9.0:*:*:*:*:*:*:*
# Microsoft Defender for Business          → NOT_FOUND
# OpenVPN Access Server                    → cpe:2.3:a:openvpn:openvpn_access_server:1.8.5:*:*:*:*:*:*:*
# Windows Server VPN                       → NOT_FOUND
# Adobe Acrobat Reader DC                  → cpe:2.3:a:adobe:acrobat_reader_dc:2015.008.20082:*:*:*:continuous:*:*:*
# Windows Server 2016/2019/2022            → NOT_FOUND
# Windows 10/11 Enterprise                 → NOT_FOUND
# Red Hat Enterprise Linux (RHEL)          → cpe:2.3:o:redhat:enterprise_linux:7.0:*:*:*:*:*:*:*
# CentOS/Ubuntu LTS                        → NOT_FOUND
# VMware vSphere ESXi                      → cpe:2.3:a:vmware:vsphere_esxi:6.0:*:*:*:*:*:*:*
# Microsoft Hyper-V                        → cpe:2.3:h:cisco:nexus_1000v:-:*:*:*:*:microsoft_hyper-v:*:*
# SAP S/4HANA Finance                      → cpe:2.3:a:sap:s\/4hana_finance:128:*:*:*:sapscore:*:*:*
# SAP ECC Financials                       → NOT_FOUND
# Oracle E-Business Suite Financials       → NOT_FOUND
# Oracle NetSuite                          → NOT_FOUND
# Microsoft Dynamics 365 Finance & Operations → NOT_FOUND
# Workday Financial Management             → NOT_FOUND
# Infor CloudSuite Financials              → NOT_FOUND
# Thomson Reuters ONESOURCE                → NOT_FOUND
# Vertex Indirect Tax                      → NOT_FOUND
# CCH Axcess Tax/ProSystem fx Tax          → NOT_FOUND
# TeamMate Analytics                       → NOT_FOUND
# Galvanize HighBond                       → NOT_FOUND
# ACL GRC                                  → NOT_FOUND
# AuditBoard                               → NOT_FOUND
# CaseWare IDEA Server                     → NOT_FOUND
# Microsoft SharePoint Online              → cpe:2.3:a:microsoft:sharepoint_online:-:*:*:*:*:*:*:*
# SharePoint Server                        → cpe:2.3:a:microsoft:sharepoint_portal_server:2003:*:*:*:*:*:*:*
# OpenText                                 → cpe:2.3:a:opentext:administration_client:10.1.0.271:*:*:*:*:*:*:*
# Alfresco                                 → cpe:2.3:a:alfresco:alfresco:4.1.6.13:*:*:*:enterprise:*:*:*
# DocuSign                                 → NOT_FOUND
# Microsoft Power BI                       → cpe:2.3:a:microsoft:power_bi_report_server:-:*:*:*:*:*:*:*
# Tableau Server                           → cpe:2.3:a:tableausoftware:tableau_server:8.0:*:*:*:*:*:*:*
# SAP BusinessObjects                      → cpe:2.3:a:sap:businessobjects:-:*:*:*:*:*:*:*
# Microsoft 365 Enterprise E3/E5           → NOT_FOUND
# Slack                                    → cpe:2.3:o:slackware:slackware_linux:10.0:*:*:*:*:*:*:*
# Citrix Workspace                         → cpe:2.3:a:citrix:workspace:1904:*:*:*:*:windows:*:*
# Microsoft Exchange Server                → cpe:2.3:a:microsoft:exchange_server:-:*:*:*:*:*:*:*
# Microsoft Teams                          → cpe:2.3:a:microsoft:teams:-:*:*:*:*:*:*:*
# Oracle Databases (12c/19c)               → NOT_FOUND
# Microsoft SQL Server Enterprise          → cpe:2.3:a:microsoft:sql_server:2012:-:enterprise:*:*:*:*:*
# Snowflake                                → cpe:2.3:a:snowflake:snowflake-connector-python:-:*:*:*:*:*:*:*
# Amazon Redshift                          → cpe:2.3:a:amazon:amazon_web_services_redshift_java_database_connectivity_driver:2.0.0.1:*:*:*:*:*:*:*
# Palo Alto Networks                       → cpe:2.3:o:altaware:palo_alto_networks_panos:4.0.0:*:*:*:*:*:*:*
# Fortinet FortiGate                       → cpe:2.3:h:fortinet:fortigate-5020:-:*:*:*:*:*:*:*
# Cisco Firepower                          → cpe:2.3:o:cisco:firepower_extensible_operating_system:1.1\(1.86\):*:*:*:*:*:*:*
# CrowdStrike Falcon                       → cpe:2.3:a:crowdstrike:falcon:6.31.14505.0:*:*:*:*:*:*:*
# Microsoft Defender for Endpoint          → cpe:2.3:a:microsoft:defender_for_endpoint:-:*:*:*:*:-:*:*
# Snort                                    → cpe:2.3:a:snort:snort:-:*:*:*:*:*:*:*
# Suricata                                 → cpe:2.3:a:openinfosecfoundation:suricata:2.0:rc_1:*:*:*:*:*:*
# Tenable Nessus                           → cpe:2.3:a:tenable:nessus:4.4.1.15078:*:*:*:*:*:x64:*
# Splunk Enterprise                        → cpe:2.3:a:splunk:splunk:6.1.3:*:*:*:enterprise:*:*:*
# IBM QRadar                               → cpe:2.3:a:ibm:qradar_security_information_and_event_manager:7.0.0:*:*:*:*:*:*:*
# Azure Sentinel                           → cpe:2.3:a:microsoft:azure_sentinel:-:*:*:*:*:*:*:*
# Chrome Enterprise                        → cpe:2.3:a:rapid7:appspider:3.8.189:*:*:*:enterprise:chrome:*:*
# Edge (Chromium)                          → NOT_FOUND
# Firefox ESR                              → cpe:2.3:a:mozilla:firefox_esr:10.0.3:*:*:*:*:*:*:*
# Adobe Acrobat Pro DC                     → NOT_FOUND
# Foxit PhantomPDF                         → cpe:2.3:a:foxitsoftware:phantompdf:7.1.3.320:*:*:*:*:*:*:*
#
# ✓  Saved mapping file → ..\data\smb_software_to_cpe.csv

# %% [markdown]
# # F1. Asset Inventory: Ingesting CPEs

# %% [markdown]
# Before CVEs can be ingested and processed for risk scoring, ``cpe_name``s must be identified and ingested as this is a required parameter when using the NVD CVE API. When no ``cpe_name`` is defined in the NVD CVE API call, all ``cpe_names`` are returned.
#
# ## Scope Management
#
# For the purposes of managing the scope of this application tool:
#
# * It is important to note that each CPE is likely to have multiple CVEs.
# * In some cases, a CPE can have hundreds (100's) of CVEs
#     * especially if the CPE is associated with a well-established product (e.g. Windows products)
# * When saving CPEs to the ``cpe_whitelist.csv``, only save the CPEs necessary for inventorying assets
#     * improves risk scoring and overall application performance
#     * prevents system errors/disruptions
#
# ## Keyword Search Tips
#
# Because this search engine is __not__ an exact keyword search, it is recommended that users:
# * start with vendor name only (e.g. Adobe)
# * refine search by adding product keyword (e.g. Acrobat)
# * further refine search by adding version number (e.g. 20.004.30006)
#
# ## Intended Purpose of Code
#
# The below code was generated by AI to create a simple to use tool that interacts with the NVD CPE API.
#
# Key features:
# * User input to keyword search the CPE API
# * Machine outputs results
# * Prompts user with a yes/no/exit scenario before saving results to file
# * Saves search results to "../data/cpe_whitelist.csv"
#     * Does not overwrite previous outputs to file
#     * Appends new outputs to existing outputs in file

# %%
import csv, json, os, time, urllib.parse, requests, re
from pathlib import Path

# --- config -----------------------------------------------------------
api_url   = "https://services.nvd.nist.gov/rest/json/cpes/2.0"
api_key = "ea5501a5-24fe-4720-80e3-2abed401d92f"
# stay well under the 5-sec/req soft limit
rate_secs = 1.2
whitelist = Path("../data/cpe_whitelist.csv")
#assets = Path("../data/assets.csv")
header = ['Title', 'cpeName']
# ----------------------------------------------------------------------

# --- function to search the CPE API -----------------------------------
def search_cpe_names(keyword):
    all_results = []
    start_index = 0
    results_per_page = 100  # Increase page size (max is 1000)
    
    headers = {
        "apiKey": api_key
    }

    while True:
        params = {
            "keywordSearch": keyword,
            "resultsPerPage": results_per_page,
            "startIndex": start_index
        }
        
        response = requests.get(api_url, params=params, headers=headers)
        
        if response.status_code != 200:
            print(f"Error fetching data for '{keyword}': {response.status_code} - {response.text}")
            break
        
        data = response.json()
        cpe_matches = data.get('products', [])
        if not cpe_matches:
            break
        
        for item in cpe_matches:
            metadata = item.get('cpe', {}).get('titles', [])
            title = next((t['title'] for t in metadata if t.get('lang') == 'en'), metadata[0]['title'] if metadata else '')
            cpe_uri = item.get('cpe', {}).get('cpeName', '')
            if cpe_uri:
                all_results.append({'title': title, 'cpeName': cpe_uri})
        
        total_results = data.get('totalResults', 0)
        start_index += results_per_page
        
        if start_index >= total_results:
            break
        
        time.sleep(rate_secs) #be nice to the API
    
    return all_results

# --- main interactive loop ---------------------------------------------
while True:
    search_input = input("Enter product search keywords separated by commas (or type 'exit' to quit): ").strip()
    if search_input.lower() == "exit" or search_input.lower() == "e":
        print("Exiting program. Goodbye!")
        break

    search_keywords = [kw.strip() for kw in search_input.split(',')]
    print("Search Keywords:", search_keywords)

    all_results = []
    for keyword in search_keywords:
        if keyword.lower() == "exit" or keyword.lower() == "e":
            print("Exiting program. Goodbye!")
            break
        time.sleep(rate_secs)
        matches = search_cpe_names(keyword)
        print(f"Number of matching results: {len(matches)}")
        print(f"\nMatches for '{keyword}':")
        if matches:
            for match in matches:
                print(f"   Title: {match['title']}")
                print(f" - CPE Name: {match['cpeName']}")
        else:
            print("No matches found.")
        all_results.extend(matches)

    if all_results:
        while True:
            save_input = input(f"\nDo you want to save {len(matches)} results to file? (yes/no/exit): ").strip().lower()
            if save_input == "yes" or save_input == "y":
                write_header = True
                if whitelist.exists():
                    with open(whitelist, "r", encoding='utf-8') as csvfile:
                        reader = csv.reader(csvfile)
                        first_row = next(reader, None)
                        if first_row and all(header in first_row for header in header):
                            write_header = False
                with open(whitelist, "a", newline='', encoding='utf-8') as csvfile:
                    writer = csv.writer(csvfile)
                    if write_header:
                        writer.writerow(header)
                    for result in all_results:
                        writer.writerow([result['title'], result['cpeName']])
                print(f"\n{len(matches)} results appended to {whitelist.resolve()}")
                break  # exit the save prompt loop
            elif save_input == "no" or save_input == "n":
                print("\nYou chose not to save. Please enter new keywords.")
                break  # exit the save prompt loop
            elif save_input == "exit" or save_input == "e":
                print("Exiting program. Goodbye!")
                break
            else:
                print("Invalid input. Please enter 'yes', 'no', or 'exit'.")
    else:
        print("\nNo results to save. Please enter new keywords.")
# Out:
# Enter product search keywords separated by commas (or type 'exit' to quit):  Tableau Desktop
# Search Keywords: ['Tableau Desktop']
# Number of matching results: 277
#
# Matches for 'Tableau Desktop':
#    Title: Schneider Electric Tableau Desktop 10.1.3
#  - CPE Name: cpe:2.3:a:schneider_electric:tableau_desktop:10.1.3:*:*:*:*:*:*:*
#    Title: Schneider Electric Tableau Desktop 7.0
#  - CPE Name: cpe:2.3:a:schneider_electric:tableau_desktop:7.0:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.19
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.19:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.20
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.20:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.21
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.21:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.0.22
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.0.22:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.19
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.19:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.20
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.20:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.21
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.21:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.22
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.22:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.23
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.23:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.1.24
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.1.24:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.19
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.19:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.20
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.20:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.21
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.21:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.22
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.22:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.23
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.23:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.2.24
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.2.24:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.19
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.19:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.20
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.20:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.21
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.21:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.22
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.22:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.23
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.23:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.24
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.24:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.25
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.25:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.3.26
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.3.26:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.19
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.19:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.20
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.20:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.21
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.21:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.4.22
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.4.22:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.19
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.19:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.20
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.20:*:*:*:*:*:*:*
#    Title: Tableau Desktop 10.5.21
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:10.5.21:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.1.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.1.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.2.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.2.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2018.3.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2018.3.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.1.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.1.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.2.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.2.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.3.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.3.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.3.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.3.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4:*:*:*:*:*:*:*
#    Title: Tableau Public Desktop 10.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_public_desktop:10.2:*:*:*:*:*:*:*
#    Title: Tableau Public Desktop 10.2.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_public_desktop:10.2.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.16
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.16:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.17
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.17:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2019.4.18
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2019.4.18:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.13
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.13:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.14
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.14:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.1.15
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.1.15:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.8
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.8:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.9
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.9:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.10
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.10:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.11
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.11:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.2.12
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.2.12:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.5
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.5:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.6
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.6:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.3.7
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.3.7:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.4
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.4:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.4.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.4.1:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.4.2
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.4.2:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2020.4.3
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2020.4.3:*:*:*:*:*:*:*
#    Title: Tableau Desktop 2021.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2021.1:*:*:*:*:*:*:*
#    Title: Schneider Electric Tableau Desktop 7.0
#  - CPE Name: cpe:2.3:a:schneider-electric:tableau_desktop:7.0:*:*:*:*:*:*:*
#    Title: Schneider Electric Tableau Desktop 10.1.3
#  - CPE Name: cpe:2.3:a:schneider-electric:tableau_desktop:10.1.3:*:*:*:*:*:*:*
# Do you want to save 277 results to file? (yes/no/exit):  Tableau Desktop 2021.1
# Invalid input. Please enter 'yes', 'no', or 'exit'.
# Do you want to save 277 results to file? (yes/no/exit):  n
# You chose not to save. Please enter new keywords.
# Enter product search keywords separated by commas (or type 'exit' to quit):  Tableau Desktop 2021.1
# Search Keywords: ['Tableau Desktop 2021.1']
# Number of matching results: 1
#
# Matches for 'Tableau Desktop 2021.1':
#    Title: Tableau Desktop 2021.1
#  - CPE Name: cpe:2.3:a:tableau:tableau_desktop:2021.1:*:*:*:*:*:*:*
# Do you want to save 1 results to file? (yes/no/exit):  y
# 1 results appended to C:\Users\hgbtx\Desktop\MIS433\final-project\cyber-risk-scoring\data\cpe_whitelist.csv
# Enter product search keywords separated by commas (or type 'exit' to quit):  e
# Exiting program. Goodbye!

# %% [markdown]
# can there be a:
# * undo feature
# * way to include a column that records the date and time the entry was written to the file

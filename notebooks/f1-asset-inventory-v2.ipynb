# %% [markdown]
# # F1. Asset Inventory: Ingesting CPEs

# %% [markdown]
# Before CVEs can be ingested and processed for risk scoring, ``cpe_name``s must be identified and ingested as this is a required parameter when using the NVD CVE API. When no ``cpe_name`` is defined in the NVD CVE API call, all ``cpe_names`` are returned.
#
# ## Scope Management
#
# For the purposes of managing the scope of this application tool:
#
# * It is important to note that each CPE is likely to have multiple CVEs.
# * In some cases, a CPE can have hundreds (100's) of CVEs
#     * especially if the CPE is associated with a well-established product (e.g. Windows products)
# * When saving CPEs to the ``cpe_whitelist.csv``, only save the CPEs necessary for inventorying assets
#     * improves risk scoring and overall application performance
#     * prevents system errors/disruptions
#
# ## Keyword Search Tips
#
# Because this search engine is __not__ an exact keyword search, it is recommended that users:
# * start with vendor name only (e.g. Adobe)
# * refine search by adding product keyword (e.g. Acrobat)
# * further refine search by adding version number (e.g. 20.004.30006)
#
# ## Intended Purpose of Code
#
# The below code was generated by AI to create a simple to use tool that interacts with the NVD CPE API.
#
# Key features:
# * User input to keyword search the CPE API
# * Machine outputs results
# * Prompts user with a yes/no/exit scenario before saving results to file
# * Saves search results to "../data/cpe_whitelist.csv"
#     * Does not overwrite previous outputs to file
#     * Appends new outputs to existing outputs in file

# %%
import csv, time, requests, os
from pathlib import Path
from datetime import datetime

# --- config -----------------------------------------------------------
api_url = "https://services.nvd.nist.gov/rest/json/cpes/2.0"
api_key = "ea5501a5-24fe-4720-80e3-2abed401d92f"
rate_secs = 1.2
whitelist = Path("../data/cpe_whitelist.csv")
header = ['WrittenAt', 'Title', 'cpeName']
UNDO_LOG = Path("../data/cpe_undo_log.csv")
undo_header = ['UnwrittenAt', 'Title', 'cpeName']
# ----------------------------------------------------------------------

def search_cpe_names(keyword):
    all_results = []
    start_index = 0
    results_per_page = 100
    headers = {"apiKey": api_key}
    while True:
        params = {
            "keywordSearch": keyword,
            "resultsPerPage": results_per_page,
            "startIndex": start_index
        }
        response = requests.get(api_url, params=params, headers=headers)
        if response.status_code != 200:
            print(f"Error fetching data for '{keyword}': {response.status_code} - {response.text}")
            break
        data = response.json()
        cpe_matches = data.get('products', [])
        if not cpe_matches:
            break
        for item in cpe_matches:
            metadata = item.get('cpe', {}).get('titles', [])
            title = next((t['title'] for t in metadata if t.get('lang') == 'en'), metadata[0]['title'] if metadata else '')
            cpe_uri = item.get('cpe', {}).get('cpeName', '')
            if cpe_uri:
                all_results.append({'title': title, 'cpeName': cpe_uri})
        total_results = data.get('totalResults', 0)
        start_index += results_per_page
        if start_index >= total_results:
            break
        time.sleep(rate_secs)
    return all_results

def write_entries_to_csv(entries, path, header):
    write_header = not path.exists() or os.path.getsize(path) == 0
    now = datetime.now().isoformat(timespec='milliseconds')
    rows_to_write = [[now, e['title'], e['cpeName']] for e in entries]
    with open(path, "a", newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        if write_header:
            writer.writerow(header)
        writer.writerows(rows_to_write)
    return now, len(rows_to_write)

def log_removal_to_undo_log(removed_rows, undo_log, undo_header):
    undo_write_header = not undo_log.exists() or os.path.getsize(undo_log) == 0
    now = datetime.now().isoformat(timespec='milliseconds')
    rows_to_log = [[now, title, cpename] for _, title, cpename in removed_rows]
    with open(undo_log, "a", newline='', encoding='utf-8') as undofile:
        undowriter = csv.writer(undofile)
        if undo_write_header:
            undowriter.writerow(undo_header)
        undowriter.writerows(rows_to_log)

def undo_last_write(path, header, undo_log, undo_header):
    # Remove last batch of rows from whitelist and record them in undo log with UnwrittenAt
    with open(path, "r", encoding='utf-8') as infile:
        lines = list(csv.reader(infile))
    if lines and lines[0] == header:
        header_row = lines[0]
        data_rows = lines[1:]
    else:
        header_row = header
        data_rows = lines
    if not data_rows:
        print("No record(s) found.")
        return
    # Find the most recent WrittenAt timestamp (last batch)
    last_written_at = data_rows[-1][0]
    rows_to_remove = [row for row in data_rows if row[0] == last_written_at]
    if not rows_to_remove:
        print("No record batch found.")
        return
    # Remove these rows from data_rows
    remaining_rows = [row for row in data_rows if row[0] != last_written_at]
    with open(path, "w", newline='', encoding='utf-8') as outfile:
        writer = csv.writer(outfile)
        writer.writerow(header_row)
        writer.writerows(remaining_rows)
    # Log these removals to undo log with UnwrittenAt
    log_removal_to_undo_log(rows_to_remove, undo_log, undo_header)
    print(f"Undid last write: removed {len(rows_to_remove)} rows and logged them to the undo log.")

def main():
    while True:
        user_input = input("Enter keywords, or type 'undo' to undo last write, or 'exit': ").strip()
        if user_input.lower() in ("exit", "e"):
            print("Exiting program. Goodbye!")
            break
        if user_input.lower() == "undo":
            undo_last_write(whitelist, header, UNDO_LOG, undo_header)
            continue
        search_keywords = [kw.strip() for kw in user_input.split(',')]
        print("Search Keywords:", search_keywords)
        all_results = []
        for keyword in search_keywords:
            if keyword.lower() in ("exit", "e"):
                print("Exiting program. Goodbye!")
                return
            time.sleep(rate_secs)
            matches = search_cpe_names(keyword)
            print(f"Number of matching results: {len(matches)}")
            print(f"\nMatches for '{keyword}':")
            if matches:
                for match in matches:
                    print(f"   Title: {match['title']}")
                    print(f" - CPE Name: {match['cpeName']}")
            else:
                print("No matches found.")
            all_results.extend(matches)
        if all_results:
            while True:
                save_input = input(f"\nDo you want to save {len(all_results)} results to file? (yes/no/exit): ").strip().lower()
                if save_input in ("yes", "y"):
                    now, nrows = write_entries_to_csv(all_results, whitelist, header)
                    print(f"\n{nrows} results appended to {whitelist.resolve()} at {now}")
                    break
                elif save_input in ("no", "n"):
                    print("\nYou chose not to save. Please enter new keywords.")
                    break
                elif save_input in ("exit", "e"):
                    print("Exiting program. Goodbye!")
                    return
                else:
                    print("Invalid input. Please enter 'yes', 'no', or 'exit'.")
        else:
            print("\nNo results to save. Please enter new keywords.")

if __name__ == "__main__":
    main()
# Out:
# Enter keywords, or type 'undo' to undo last write, or 'exit':  microsoft exchange
# Search Keywords: ['microsoft exchange']
# Number of matching results: 286
#
# Matches for 'microsoft exchange':
#    Title: Computer Associates Unicenter Management Microsoft Exchange
#  - CPE Name: cpe:2.3:a:ca:unicenter_management_microsoft_exchange:-:*:*:*:*:*:*:*
#    Title: Microsoft exchange_instant_messenger
#  - CPE Name: cpe:2.3:a:microsoft:exchange_instant_messenger:-:*:*:*:*:*:*:*
#    Title: Microsoft exchange_instant_messenger 4.5
#  - CPE Name: cpe:2.3:a:microsoft:msn_messenger_service_for_exchange:4.5:*:*:*:*:*:*:*
#    Title: Microsoft exchange_instant_messenger 4.6
#  - CPE Name: cpe:2.3:a:microsoft:msn_messenger_service_for_exchange:4.6:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:-:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 4.0
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.0
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.0:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.5:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2000
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2000:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2003
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2003:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2007
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.0 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.0:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.0 Service Pack 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.0:sp2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.5 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.5:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.5 Service Pack 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.5:sp2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.5 Service Pack 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.5:sp3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.5 Service Pack 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.5:sp4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2000 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2000:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2000 Service Pack 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2000:sp2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2000 Service Pack 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2000:sp3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2003 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2003:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2003 Service Pack 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2003:sp2:*:*:*:*:*:*
#    Title: Symantec Mail Security 4.5 build736 Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:4.5_build_736:*:exchange:*:*:*:*:*
#    Title: Symantec Mail Security 4.5 build741 Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:4.5_build_741:*:exchange:*:*:*:*:*
#    Title: Symantec Mail Security 4.6 build97 Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:4.6_build_97:*:exchange:*:*:*:*:*
#    Title: Microsoft exchange_instant_messenger 4.5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_instant_messenger:4.5:*:*:*:*:*:*:*
#    Title: Microsoft exchange_instant_messenger 4.6
#  - CPE Name: cpe:2.3:a:microsoft:exchange_instant_messenger:4.6:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:-:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 4.0
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:4.0:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.0
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.0:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.5:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2000
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2000:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2003
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2003:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2007
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2007:*:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.0 sp1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.0:sp1:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.0 sp2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.0:sp2:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.5 sp1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.5:sp1:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.5 sp2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.5:sp2:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.5 sp3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.5:sp3:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 5.5 sp4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:5.5:sp4:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2000 sp1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2000:sp1:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2000 sp2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2000:sp2:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2000 sp3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2000:sp3:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2003 sp1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2003:sp1:*:*:*:*:*:*
#    Title: Microsoft exchange_srv 2003 sp2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_srv:2003:sp2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 for x64 based systems
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2:x64:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 for x64 based systems
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:-:x64:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp3:*:*:*:*:*:*
#    Title: Google Apps Migration For Microsoft Exchange 2.2.756.1127
#  - CPE Name: cpe:2.3:a:google:apps_migration_for_microsoft_exchange:2.2.756.1127:*:*:*:*:*:*:*
#    Title: Mcafee Security For Microsoft Exchange 7.6.7718.105
#  - CPE Name: cpe:2.3:a:mcafee:security_for_microsoft_exchange:7.6.7718.105:*:*:*:*:*:*:*
#    Title: Quest Intrust Knowledge Pack For Microsoft Exchange Server 10.2.5.1024
#  - CPE Name: cpe:2.3:a:quest:intrust_knowledge_pack_for_microsoft_exchange_server:10.2.5.1024:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.5
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_3:*:*:*:*:*:*
#    Title: Microsoft Forefront Protection 2010 for Exchange Server
#  - CPE Name: cpe:2.3:a:microsoft:microsoft_forefront_protection_2010:-:*:*:*:*:exchange_server:*:*
#    Title: BlackBerry Enterprise Server Express for Microsoft Exchange Server 5.0.4
#  - CPE Name: cpe:2.3:a:blackberry:enterprise_server_express:5.0.4:*:*:*:*:exchange_server:*:*
#    Title: BlackBerry Enterprise Server Express for Microsoft Exchange Server 5.0.4 Maintenance Release 6
#  - CPE Name: cpe:2.3:a:blackberry:enterprise_server:5.0.4:mr6:*:*:*:exchange_server:*:*
#    Title: IBM Data Protection for Microsoft Exchange Server 6.1
#  - CPE Name: cpe:2.3:a:ibm:data_protection:6.1:*:*:*:*:exchange_server:*:*
#    Title: IBM Data Protection for Microsoft Exchange Server 6.3
#  - CPE Name: cpe:2.3:a:ibm:data_protection:6.3:*:*:*:*:exchange_server:*:*
#    Title: IBM FlashCopy Manager for Microsoft Exchange Server 2.1
#  - CPE Name: cpe:2.3:a:ibm:flashcopy_manager:2.1:*:*:*:*:exchange_server:*:*
#    Title: IBM FlashCopy Manager for Microsoft Exchange Server 2.2
#  - CPE Name: cpe:2.3:a:ibm:flashcopy_manager:2.2:*:*:*:*:exchange_server:*:*
#    Title: IBM FlashCopy Manager for Microsoft Exchange Server 3.1
#  - CPE Name: cpe:2.3:a:ibm:flashcopy_manager:3.1:*:*:*:*:exchange_server:*:*
#    Title: IBM Data Protection for Microsoft Exchange Server 6.1.3.4
#  - CPE Name: cpe:2.3:a:ibm:data_protection:6.1.3.4:*:*:*:*:exchange_server:*:*
#    Title: IBM Data Protection for Microsoft Exchange Server 6.3.1
#  - CPE Name: cpe:2.3:a:ibm:data_protection:6.3.1:*:*:*:*:exchange_server:*:*
#    Title: IBM FlashCopy Manager for Microsoft Exchange Server 3.1.1
#  - CPE Name: cpe:2.3:a:ibm:flashcopy_manager:3.1.1:*:*:*:*:exchange_server:*:*
#    Title: F-Secure Anti-Virus for Microsoft Exchange Server 9.00
#  - CPE Name: cpe:2.3:a:f-secure:anti-virus:9.00:*:*:*:*:exchange_server:*:*
#    Title: F-Secure Anti-Virus for Microsoft Exchange Server 9.10
#  - CPE Name: cpe:2.3:a:f-secure:anti-virus:9.10:*:*:*:*:exchange_server:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 7
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_7:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 11
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_11:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 10
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_10:*:*:*:*:*:*
#    Title: HP Sizer For Microsoft Exchange Server 2010 16.12.0
#  - CPE Name: cpe:2.3:a:hp:sizer_for_microsoft_exchange_server_2010:16.12.0:*:*:*:*:*:*:*
#    Title: HP Sizer For Microsoft Exchange Server 2013 16.12.0
#  - CPE Name: cpe:2.3:a:hp:sizer_for_microsoft_exchange_server_2013:16.12.0:*:*:*:*:*:*:*
#    Title: HP Sizer For Microsoft Exchange Server 2016 16.12.0
#  - CPE Name: cpe:2.3:a:hp:sizer_for_microsoft_exchange_server_2016:16.12.0:*:*:*:*:*:*:*
#    Title: Symantec Mail Security for Microsoft Exchange 7.5.4
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5.4:*:*:*:*:*:*:*
#    Title: Symantec Mail Security for Microsoft Exchange 7.0.4
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.0.4:*:*:*:*:*:*:*
#    Title: Symantec Mail Security for Microsoft Exchange 6.5.8
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5.8:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 13
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_13:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 16
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_16:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_5:*:*:*:*:*:*
#    Title: Broadcom Unicenter Management 4.0 Microsoft Exchange Edition
#  - CPE Name: cpe:2.3:a:broadcom:unicenter_management:4.0:*:microsoft_exchange:*:*:*:*:*
#    Title: Broadcom Unicenter Management 4.1 Microsoft Exchange Edition
#  - CPE Name: cpe:2.3:a:broadcom:unicenter_management:4.1:*:microsoft_exchange:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 19
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_19:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 20
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_20:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 8
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_8:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 9
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_9:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 12
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_12:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 8
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_8:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 14
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_14:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 17
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_17:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 6
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_6:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 7
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_7:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 18
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_18:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage FlashCopy Manager for Microsoft Exchange Server 2.2
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_flashcopy_manager_for_microsoft_exchange_server:2.2:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage FlashCopy Manager for Microsoft Exchange Server 2.2.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_flashcopy_manager_for_microsoft_exchange_server:2.2.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage FlashCopy Manager for Microsoft Exchange Server 3.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_flashcopy_manager_for_microsoft_exchange_server:3.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage FlashCopy Manager for Microsoft Exchange Server 3.2
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_flashcopy_manager_for_microsoft_exchange_server:3.2:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage FlashCopy Manager for Microsoft Exchange Server 3.2.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_flashcopy_manager_for_microsoft_exchange_server:3.2.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 5.5
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:5.5:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 5.5.1.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:5.5.1.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.1.2
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.1.2:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.1.3
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.1.3:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.3
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.3:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.3.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.3.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.3.1.5
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.3.1.5:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.4
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.4:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.4.0.2
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.4.0.2:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.4.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.4.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 6.4.1.7
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:6.4.1.7:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 7.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:7.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 7.1.1
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:7.1.1:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 7.1.2
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:7.1.2:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 7.1.3
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:7.1.3:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 7.1.4
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:7.1.4:*:*:*:*:*:*:*
#    Title: IBM Tivoli Storage Manager for Mail Data Protection for Microsoft Exchange Server 7.1.6
#  - CPE Name: cpe:2.3:a:ibm:tivoli_storage_manager_for_mail_data_protection_for_microsoft_exchange_server:7.1.6:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.1
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.1:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.2
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.2:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.3
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.3:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.5
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.5:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.6
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.6:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.7
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.7:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.8
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.8:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.9
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.9:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.10
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.10:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.11
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.11:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.12
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.12:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.0.13
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.0.13:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.5.1
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5.1:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.5.2
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5.2:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.5.5
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5.5:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.5.6
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5.6:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 6.5.7
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:6.5.7:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.0
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.0:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.0.1
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.0.1:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.0.2
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.0.2:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.0.3
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.0.3:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.5
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.5.1
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5.1:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.5.2
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5.2:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.5.3
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5.3:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.5.5
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5.5:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.5.6
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.5.6:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.9
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.9:*:*:*:*:*:*:*
#    Title: Symantec Mail Security For Microsoft Exchange 7.9.1
#  - CPE Name: cpe:2.3:a:symantec:mail_security_for_microsoft_exchange:7.9.1:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 23
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_23:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 13
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_13:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 10
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_10:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 11
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_11:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 12
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_12:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 13
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_13:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 14
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_14:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 15
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_15:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 16
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_16:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 17
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_17:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 18
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_18:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 19
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_19:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 20
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_20:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 21
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_21:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 22
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_22:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 23
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_23:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 24
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_24:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 25
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_25:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 26
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_26:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 27
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_27:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 28
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_28:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 29
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_29:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_5:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 6
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_6:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 7
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_7:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 8
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_8:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 9
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_9:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 15
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_15:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 21
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_21:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 22
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_22:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_5:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 6
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_6:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013 Cumulative Update 9
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:cumulative_update_9:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 10
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_10:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 11
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_11:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 12
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_12:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 14
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_14:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_3:*:*:*:*:*:*
#    Title: Symantec Mail Security for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:-:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.1 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.1:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.2 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.2:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.3 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.3:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.5 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.5:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.6 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.6:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.7 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.7:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.8 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.8:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.9 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.9:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.10 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.10:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.11 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.11:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.12 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.12:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.0.13 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.0.13:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.5 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.5:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.5.1 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.5.1:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.5.5 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.5.5:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.5.6 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.5.6:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.5.7 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.5.7:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 6.5.8 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:6.5.8:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.0 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.0:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.0.1 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.0.1:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.0.2 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.0.2:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.0.3 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.0.3:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.0.4 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.0.4:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5.1 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5.1:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5.2 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5.2:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5.3 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5.3:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5.4 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5.4:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5.5 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5.5:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.5.6 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.5.6:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.9 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.9:*:*:*:*:microsoft_exchange:*:*
#    Title: Symantec Mail Security 7.9.1 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:symantec:mail_security:7.9.1:*:*:*:*:microsoft_exchange:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Update Rollup 30
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_30:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 15
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_15:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 16
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_16:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_5:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2000
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2000:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2003
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2003:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2013
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2013:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.0
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.0:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 5.5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:5.5:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 4.0
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 4.0 Service Pack 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:sp1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 4.0 Service Pack 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:sp2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 4.0 Service Pack 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:sp3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 4.0 Service Pack 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:sp4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 4.0 Service Pack 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:4.0:sp5:*:*:*:*:*:*
#    Title: Trend Micro ScanMail 14.0 for Microsoft Exchange
#  - CPE Name: cpe:2.3:a:trendmicro:scanmail:14.0:*:*:*:*:microsoft_exchange:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 on x64
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2:*:*:*:*:x64:*
#    Title: Microsoft Exchange Server 2007 Service Pack 1 on x64
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp1:*:*:*:*:x64:*
#    Title: Microsoft Exchange Server 2010 on x64
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:-:*:*:*:*:x64:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 Update Rollup 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2_update_rollup_1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 Update Rollup 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2_update_rollup_2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 Update Rollup 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2_update_rollup_3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 Update Rollup 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2_update_rollup_4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2007 Service Pack 2 Update Rollup 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2007:sp2_update_rollup_5:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup20
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup20:*:*:*:*:*:*
#    Title: Trend Micro ScanMail for Microsoft Exchange (SMEX) 12.0
#  - CPE Name: cpe:2.3:a:trendmicro:scanmail:12.0:*:*:*:*:microsoft_exchange:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 17
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_17:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 6
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_6:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2010 Service Pack 3 Rollup 31
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2010:sp3_rollup_31:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 18
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_18:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 7
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_7:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 8
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_8:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 19
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_19:*:*:*:*:*:*
#    Title: Broadcom Unicenter Management Microsoft Exchange
#  - CPE Name: cpe:2.3:a:broadcom:unicenter_management_microsoft_exchange:-:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 20
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_20:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 9
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_9:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 21
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_21:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 10
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_10:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 22
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_22:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 11
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_11:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2016 Cumulative Update 23
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2016:cumulative_update_23:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 12
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_12:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 13
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_13:*:*:*:*:*:*
#    Title: Microsoft Exchange Online
#  - CPE Name: cpe:2.3:a:microsoft:exchange_online:-:*:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 14
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_14:*:*:*:*:*:*
# Do you want to save 286 results to file? (yes/no/exit):  Microsoft Exchange Server 2019
# Invalid input. Please enter 'yes', 'no', or 'exit'.
# Do you want to save 286 results to file? (yes/no/exit):  n
# You chose not to save. Please enter new keywords.
# Enter keywords, or type 'undo' to undo last write, or 'exit':  Microsoft Exchange Server 2019
# Search Keywords: ['Microsoft Exchange Server 2019']
# Number of matching results: 15
#
# Matches for 'Microsoft Exchange Server 2019':
#    Title: Microsoft Exchange Server 2019 Cumulative Update 1
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_1:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 2
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_2:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 3
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_3:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 4
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_4:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 5
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_5:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:-:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 6
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_6:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 7
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_7:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 8
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_8:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 9
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_9:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 10
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_10:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 11
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_11:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 12
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_12:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 13
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_13:*:*:*:*:*:*
#    Title: Microsoft Exchange Server 2019 Cumulative Update 14
#  - CPE Name: cpe:2.3:a:microsoft:exchange_server:2019:cumulative_update_14:*:*:*:*:*:*
# Do you want to save 15 results to file? (yes/no/exit):  y
# 15 results appended to C:\Users\hgbtx\Desktop\MIS433\final-project\cyber-risk-scoring\data\cpe_whitelist.csv at 2025-06-08T22:12:59.597
# Enter keywords, or type 'undo' to undo last write, or 'exit':  e
# Exiting program. Goodbye!
